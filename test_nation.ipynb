# %%
from game.tables import Base, Nation, Decisions, PlayerInfo
from sqlalchemy import inspect

# %%
nation = Nation(decisions=Decisions(game_id=1, user_id="101", round_id=0), player_info=PlayerInfo(game_id=1, user_id="101"), game_id=1, user_id="101", round_id=0)

# %%
nation2 = nation.create_nation_copy()

# %%
nation2
# Out:
# Nation(decisions=Decisions(nation=..., decision_id=None, nation_id=None, game_id=1, user_id='101', round_id=0, farm_area_fraction=0.5, production_area_fraction=0.5, LQ_goods_production_fraction=0.5, HQ_goods_production_fraction=0.5, LQ_food_production_fraction=0.33, specials_production_fraction=0.34, HQ_food_production_fraction=0.33, fossil_fuels_burned=0.0, electricity_allocated_food=0.0, electricity_allocated_goods=0.0, resources_distributed_LQfood=0.0, resources_distributed_HQfood=0.0, resources_distributed_specials=0.0, resources_distributed_LQgoods=0.0, resources_distributed_HQgoods=0.0, investments_food=0.0, investments_goods=0.0, investments_fossil_fuels=0.0, investments_renewable_electricity=0.0, investments_nuclear_electricity=0.0, investments_energy_efficiency=0.0, investments_environment=0.0, investments_human_services=0.0, imports_LQfood=0.0, imports_HQfood=0.0, imports_specials=0.0, imports_LQgoods=0.0, imports_HQgoods=0.0, imports_electricity=0.0, imports_fossil_fuels=0
# ...

# %%
print(nation.decisions.round_id)
print(nation2.decisions.round_id)
# Out:
# 0
# 1

# %%
print(nation2.decisions.electricity_allocated_food)
# Out:
# 0.0

# %%
nation.set_resources(LQfood = 600, electricity = 300)

# %%
nation.get_resources()
# Out:
# {'resources_LQfood': 600,
#  'resources_HQfood': 500.0,
#  'resources_specials': 500.0,
#  'resources_LQgoods': 500.0,
#  'resources_HQgoods': 500.0,
#  'resources_electricity': 300,
#  'resources_fossil_fuels': 500.0}

# %%
nation = Nation()
nation.elec_to_full_capacity_food()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 2
#       1 nation = Nation()
# ----> 2 nation.elec_to_full_capacity_food()
#
# File c:\Users\where\Documents\ECgame2\Nation.py:51, in Nation.elec_to_full_capacity_food(self)
#      49 @property
#      50 def elec_to_full_capacity_food(self) -> float:
# ---> 51     return self.prod_cap_food * ELECTRICITY_PER_FOOD
#
# NameError: name 'ELECTRICITY_PER_FOOD' is not defined

# %%
"asd".startswith()

# %%
import sqlalchemy
print(sqlalchemy.__version__)
# Out:
# 2.0.45
