# %%
from sqlalchemy import create_engine
from dotenv import load_dotenv
import oracledb
import os
from Nation import Base
from sqlalchemy import inspect

# %%
DB_USER = "ADMIN"
DB_PASSWORD = os.environ.get("DB_PASSWORD")
HOST = "adb.eu-stockholm-1.oraclecloud.com"
PORT = "1521"
SERVICE_NAME = "ge72a74000425b4_ecgame_tp.adb.oraclecloud.com"
DB_CONNECT_STRING = '(description= (retry_count=20)(retry_delay=3)(address=(protocol=tcps)(port=1521)(host=adb.eu-stockholm-1.oraclecloud.com))(connect_data=(service_name=ge72a74000425b4_ecgame_tp.adb.oraclecloud.com))(security=(ssl_server_dn_match=yes)))'
connection_url = f"oracle+oracledb://{DB_USER}:{DB_PASSWORD}@{SERVICE_NAME}"

# %%
def get_connection():
    return oracledb.connect(
        user=DB_USER,
        password=DB_PASSWORD,
        dsn=DB_CONNECT_STRING
    )

# %%
engine = create_engine("oracle+oracledb://", creator=get_connection, echo=True)

# %%
Base.metadata.create_all(engine)
# Out:
# 2025-12-20 20:16:33,266 INFO sqlalchemy.engine.Engine select sys_context( 'userenv', 'current_schema' ) from dual
# 2025-12-20 20:16:33,267 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2025-12-20 20:16:33,333 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-12-20 20:16:33,336 INFO sqlalchemy.engine.Engine SELECT tables_and_views.table_name
# FROM (SELECT a_tables.table_name AS table_name, a_tables.owner AS owner
# FROM all_tables a_tables UNION ALL SELECT a_views.view_name AS table_name, a_views.owner AS owner
# FROM all_views a_views) tables_and_views
# WHERE tables_and_views.table_name = :table_name AND tables_and_views.owner = :owner
# 2025-12-20 20:16:33,336 INFO sqlalchemy.engine.Engine [generated in 0.00069s] {'table_name': 'DECISIONS', 'owner': 'ADMIN'}
# 2025-12-20 20:16:33,355 INFO sqlalchemy.engine.Engine SELECT tables_and_views.table_name
# FROM (SELECT a_tables.table_name AS table_name, a_tables.owner AS owner
# FROM all_tables a_tables UNION ALL SELECT a_views.view_name AS table_name, a_views.owner AS owner
# FROM all_views a_views) tables_and_views
# WHERE tables_and_views.table_name = :table_name AND tables_and_views.owner = :owner
# 2025-12-20 20:16:33,355 INFO sqlalchemy.engine.Engine [cached since 0.01933s ago] {'table_name': 'PLAYER_INFO', 'owner': 'ADMIN'}
# 2025-12-20 20:16:33,369 INFO sqlalchemy.engine.Engine SELECT tables_and_views.table_name
# FROM (SELECT a_tables.table_name AS table_name, a_tables.owner AS owner
# FROM all_tables a_tables UNION ALL SELECT a_views.view_name AS table_name, a_views.owner AS owner
# FROM all_views a_views) tables_and_views
# WHERE tables_and_views.table_name = :table_name AND tables_and_views.owner = :owner
# 2025-12-20 20:16:33,369 INFO sqlalchemy.engine.Engine [cached since 0.03333s ago] {'table_name': 'NATIONS', 'owner': 'ADMIN'}
# 2025-12-20 20:16:33,383 INFO sqlalchemy.engine.Engine
# CREATE TABLE player_info (
# 	game_id INTEGER NOT NULL,
# 	user_id INTEGER NOT NULL,
# 	leader_name VARCHAR2(20 CHAR) NOT NULL,
# 	nation_name VARCHAR2(20 CHAR) NOT NULL,
# 	PRIMARY KEY (game_id, user_id)
# )
#
#
# 2025-12-20 20:16:33,384 INFO sqlalchemy.engine.Engine [no key 0.00033s] {}
# 2025-12-20 20:16:33,414 INFO sqlalchemy.engine.Engine COMMIT

# %%
inspector = inspect(engine)
tables = inspector.get_table_names()
# Out:
# 2025-12-20 20:20:25,817 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-12-20 20:20:25,817 INFO sqlalchemy.engine.Engine SELECT a_tables.table_name
# FROM all_tables a_tables
# WHERE (coalesce(a_tables.tablespace_name, :coalesce_1) NOT IN (:coalesce_2_1, :coalesce_2_2)) AND a_tables.owner = :owner_1 AND a_tables.iot_name IS NULL AND a_tables.duration IS NULL MINUS SELECT a_mviews.mview_name AS table_name
# FROM all_mviews a_mviews
# WHERE a_mviews.owner = :owner_2
# 2025-12-20 20:20:25,818 INFO sqlalchemy.engine.Engine [generated in 0.00092s] {'coalesce_1': 'no tablespace', 'owner_1': 'ADMIN', 'owner_2': 'ADMIN', 'coalesce_2_1': 'SYSTEM', 'coalesce_2_2': 'SYSAUX'}
# 2025-12-20 20:20:26,440 INFO sqlalchemy.engine.Engine ROLLBACK

# %%
Base.metadata.drop_all(engine)
# Out:
# 2025-12-20 20:22:42,480 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-12-20 20:22:42,481 INFO sqlalchemy.engine.Engine SELECT tables_and_views.table_name
# FROM (SELECT a_tables.table_name AS table_name, a_tables.owner AS owner
# FROM all_tables a_tables UNION ALL SELECT a_views.view_name AS table_name, a_views.owner AS owner
# FROM all_views a_views) tables_and_views
# WHERE tables_and_views.table_name = :table_name AND tables_and_views.owner = :owner
# 2025-12-20 20:22:42,481 INFO sqlalchemy.engine.Engine [cached since 369.1s ago] {'table_name': 'DECISIONS', 'owner': 'ADMIN'}
# 2025-12-20 20:22:42,497 INFO sqlalchemy.engine.Engine SELECT tables_and_views.table_name
# FROM (SELECT a_tables.table_name AS table_name, a_tables.owner AS owner
# FROM all_tables a_tables UNION ALL SELECT a_views.view_name AS table_name, a_views.owner AS owner
# FROM all_views a_views) tables_and_views
# WHERE tables_and_views.table_name = :table_name AND tables_and_views.owner = :owner
# 2025-12-20 20:22:42,498 INFO sqlalchemy.engine.Engine [cached since 369.2s ago] {'table_name': 'PLAYER_INFO', 'owner': 'ADMIN'}
# 2025-12-20 20:22:42,512 INFO sqlalchemy.engine.Engine SELECT tables_and_views.table_name
# FROM (SELECT a_tables.table_name AS table_name, a_tables.owner AS owner
# FROM all_tables a_tables UNION ALL SELECT a_views.view_name AS table_name, a_views.owner AS owner
# FROM all_views a_views) tables_and_views
# WHERE tables_and_views.table_name = :table_name AND tables_and_views.owner = :owner
# 2025-12-20 20:22:42,513 INFO sqlalchemy.engine.Engine [cached since 369.2s ago] {'table_name': 'NATIONS', 'owner': 'ADMIN'}
# 2025-12-20 20:22:42,527 INFO sqlalchemy.engine.Engine
# DROP TABLE decisions
# 2025-12-20 20:22:42,528 INFO sqlalchemy.engine.Engine [no key 0.00065s] {}
# 2025-12-20 20:22:42,709 INFO sqlalchemy.engine.Engine
# DROP TABLE nations
# 2025-12-20 20:22:42,709 INFO sqlalchemy.engine.Engine [no key 0.00060s] {}
# 2025-12-20 20:22:42,775 INFO sqlalchemy.engine.Engine
# DROP TABLE player_info
# 2025-12-20 20:22:42,775 INFO sqlalchemy.engine.Engine [no key 0.00034s] {}
# 2025-12-20 20:22:42,804 INFO sqlalchemy.engine.Engine COMMIT
