# %%
from sqlalchemy import create_engine
from dotenv import load_dotenv
import oracledb
import os
from game.tables import Base
from sqlalchemy import inspect
from game.DatabaseManager import DatabaseManager

# %%
manager: DatabaseManager = DatabaseManager()
# Out:
# Successfully connected to the database

# %%
manager.drop_all_tables()
manager.create_all_tables()
manager.initiate_new_game()
manager.add_new_player(user_id="auth0|694d7b2be2231460b41650cd", game_id=1, leader_name="Walde", nation_name="Waldelandia")
manager.add_new_player(user_id="321", game_id=1, leader_name="Whereee", nation_name="Wadad")
# Out:
# 2025-12-29 17:43:53,308 INFO sqlalchemy.engine.Engine select sys_context( 'userenv', 'current_schema' ) from dual
# 2025-12-29 17:43:53,309 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2025-12-29 17:43:53,374 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-12-29 17:43:53,377 INFO sqlalchemy.engine.Engine SELECT tables_and_views.table_name
# FROM (SELECT a_tables.table_name AS table_name, a_tables.owner AS owner
# FROM all_tables a_tables UNION ALL SELECT a_views.view_name AS table_name, a_views.owner AS owner
# FROM all_views a_views) tables_and_views
# WHERE tables_and_views.table_name = :table_name AND tables_and_views.owner = :owner
# 2025-12-29 17:43:53,378 INFO sqlalchemy.engine.Engine [generated in 0.00059s] {'table_name': 'GAME_INFO', 'owner': 'ADMIN'}
# 2025-12-29 17:43:53,394 INFO sqlalchemy.engine.Engine SELECT tables_and_views.table_name
# FROM (SELECT a_tables.table_name AS table_name, a_tables.owner AS owner
# ...

# %%
manager.advance_round(game_id=1)
# Out:
# 2025-12-29 17:43:59,563 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-12-29 17:43:59,564 INFO sqlalchemy.engine.Engine SELECT game_info.current_round
# FROM game_info
# WHERE game_info.game_id = :game_id_1
# 2025-12-29 17:43:59,565 INFO sqlalchemy.engine.Engine [generated in 0.00067s] {'game_id_1': 1}
# 2025-12-29 17:43:59,625 INFO sqlalchemy.engine.Engine ROLLBACK
# 2025-12-29 17:43:59,650 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# ...

# %%
manager.initiate_new_game()
# Out:
# 2025-12-29 15:41:22,210 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-12-29 15:41:22,212 INFO sqlalchemy.engine.Engine INSERT INTO game_info (num_of_rounds, current_round, num_of_players, max_num_of_players, is_active) VALUES (:num_of_rounds, :current_round, :num_of_players, :max_num_of_players, :is_active) RETURNING game_info.game_id INTO :ret_0
# 2025-12-29 15:41:22,212 INFO sqlalchemy.engine.Engine [generated in 0.00065s] {'num_of_rounds': 20, 'current_round': 0, 'num_of_players': 0, 'max_num_of_players': 12, 'is_active': 1, 'ret_0': <oracledb.Var of type DB_TYPE_VARCHAR with value None>}
# 2025-12-29 15:41:22,240 INFO sqlalchemy.engine.Engine COMMIT
# Initiated a new game

# %%
manager.add_new_player(user_id="321", game_id=1, leader_name="Where", nation_name="Wadadnd")
# Out:
# 2025-12-29 15:41:33,038 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-12-29 15:41:33,039 INFO sqlalchemy.engine.Engine INSERT INTO player_info (game_id, user_id, leader_name, nation_name, is_active) VALUES (:game_id, :user_id, :leader_name, :nation_name, :is_active)
# 2025-12-29 15:41:33,039 INFO sqlalchemy.engine.Engine [cached since 7.721s ago] {'game_id': 1, 'user_id': '321', 'leader_name': 'Where', 'nation_name': 'Wadadnd', 'is_active': 1}
# ...

# %%
manager.drop_all_tables()
# Out:
# 2025-12-29 15:41:13,263 INFO sqlalchemy.engine.Engine select sys_context( 'userenv', 'current_schema' ) from dual
# 2025-12-29 15:41:13,264 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2025-12-29 15:41:13,330 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-12-29 15:41:13,333 INFO sqlalchemy.engine.Engine SELECT tables_and_views.table_name
# FROM (SELECT a_tables.table_name AS table_name, a_tables.owner AS owner
# FROM all_tables a_tables UNION ALL SELECT a_views.view_name AS table_name, a_views.owner AS owner
# FROM all_views a_views) tables_and_views
# WHERE tables_and_views.table_name = :table_name AND tables_and_views.owner = :owner
# 2025-12-29 15:41:13,334 INFO sqlalchemy.engine.Engine [generated in 0.00070s] {'table_name': 'GAME_INFO', 'owner': 'ADMIN'}
# 2025-12-29 15:41:13,351 INFO sqlalchemy.engine.Engine SELECT tables_and_views.table_name
# FROM (SELECT a_tables.table_name AS table_name, a_tables.owner AS owner
# ...

# %%
manager.create_all_tables()
# Out:
# 2025-12-29 15:41:15,840 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-12-29 15:41:15,841 INFO sqlalchemy.engine.Engine SELECT tables_and_views.table_name
# FROM (SELECT a_tables.table_name AS table_name, a_tables.owner AS owner
# FROM all_tables a_tables UNION ALL SELECT a_views.view_name AS table_name, a_views.owner AS owner
# FROM all_views a_views) tables_and_views
# WHERE tables_and_views.table_name = :table_name AND tables_and_views.owner = :owner
# 2025-12-29 15:41:15,841 INFO sqlalchemy.engine.Engine [cached since 2.508s ago] {'table_name': 'GAME_INFO', 'owner': 'ADMIN'}
# 2025-12-29 15:41:15,856 INFO sqlalchemy.engine.Engine SELECT tables_and_views.table_name
# FROM (SELECT a_tables.table_name AS table_name, a_tables.owner AS owner
# FROM all_tables a_tables UNION ALL SELECT a_views.view_name AS table_name, a_views.owner AS owner
# FROM all_views a_views) tables_and_views
# WHERE tables_and_views.table_name = :table_name AND tables_and_views.owner = :owner
# ...

# %%
manager.initiate_new_game()
# Out:
# 2025-12-28 21:14:16,879 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-12-28 21:14:16,880 INFO sqlalchemy.engine.Engine INSERT INTO game_info (num_of_rounds, current_round, num_of_players, max_num_of_players, is_active) VALUES (:num_of_rounds, :current_round, :num_of_players, :max_num_of_players, :is_active) RETURNING game_info.game_id INTO :ret_0
# 2025-12-28 21:14:16,881 INFO sqlalchemy.engine.Engine [cached since 1890s ago] {'num_of_rounds': 20, 'current_round': 0, 'num_of_players': 0, 'max_num_of_players': 12, 'is_active': 1, 'ret_0': <oracledb.Var of type DB_TYPE_VARCHAR with value None>}
# 2025-12-28 21:14:16,909 INFO sqlalchemy.engine.Engine COMMIT
# Initiated a new game

# %%
manager.drop_all_tables()
# Out:
# 2025-12-26 23:18:05,143 INFO sqlalchemy.engine.Engine select sys_context( 'userenv', 'current_schema' ) from dual
# 2025-12-26 23:18:05,143 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2025-12-26 23:18:05,210 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-12-26 23:18:05,212 INFO sqlalchemy.engine.Engine SELECT tables_and_views.table_name
# FROM (SELECT a_tables.table_name AS table_name, a_tables.owner AS owner
# FROM all_tables a_tables UNION ALL SELECT a_views.view_name AS table_name, a_views.owner AS owner
# FROM all_views a_views) tables_and_views
# WHERE tables_and_views.table_name = :table_name AND tables_and_views.owner = :owner
# 2025-12-26 23:18:05,213 INFO sqlalchemy.engine.Engine [generated in 0.00052s] {'table_name': 'GAME_INFO', 'owner': 'ADMIN'}
# 2025-12-26 23:18:05,230 INFO sqlalchemy.engine.Engine SELECT tables_and_views.table_name
# FROM (SELECT a_tables.table_name AS table_name, a_tables.owner AS owner
# ...

# %%
def get_connection():
    return oracledb.connect(
        user=DB_USER,
        password=DB_PASSWORD,
        dsn=DB_CONNECT_STRING
    )
engine = create_engine("oracle+oracledb://", creator=get_connection, echo=True)
